# %%
import pandas as pd

e = pd.read_csv(r'/Users/vjaishnav/Desktop/Fitness_Data.csv')
e = e.reset_index()
m = e
m.drop(m.columns[[1]], axis=1, inplace=True)
m
# Out:
#                  level_0               level_2                 level_3  \
# 0                   Date  Active Energy (kcal)  Heart Rate [Min] (bpm)
# 1    2023-01-01 00:00:00                471.64                      40
# 2    2023-01-02 00:00:00                380.09                      45
# 3    2023-01-03 00:00:00                235.22                      48
# 4    2023-01-04 00:00:00                 20.09                      53
# ..                   ...                   ...                     ...
# 317  2023-11-13 00:00:00                396.36                      43
# 318  2023-11-14 00:00:00                228.81                      42
# 319  2023-11-15 00:00:00                344.65                      46
# 320  2023-11-16 00:00:00                234.87                      45
# 321  2023-11-17 00:00:00                 410.8                      45
#
#                     level_4                 level_5             level_6  \
# ...
